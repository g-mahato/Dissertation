# %%
import pandas as pd
import numpy as np
import concurrent.futures
import requests
import cloudscraper
import time
from requests.exceptions import RequestException

# %%
df = pd.read_csv('raw_dataset.csv')
df = df.drop(['gravity'], axis=1).sample(frac=0.001)
df['gravity'] = 'none'

# %%
df.shape
# Out:
# (18, 28)

# %%
def get_gravity(url):
    scraper = cloudscraper.create_scraper()
    max_retries = 1
    for attempt in range(max_retries):
        try:
            response = scraper.get(url)
            if response.status_code == 200:
                data = response.json()  # Parse the JSON response
                return data.get('predictedGravity', 'none')
            else:
                # print(f"Request failed with status code: {response.status_code}")
                # time.sleep(180)  # Wait a bit before retrying
                return 'none'
        except RequestException as e:
            # print(f"Attempt {attempt + 1} for URL {url} failed: {e}")
            if attempt == max_retries - 1:
                return 'none'

# Function to apply multithreading for concurrent requests
def fetch_gravity_concurrently(urls):
    results = []
    with concurrent.futures.ThreadPoolExecutor() as executor:
        future_to_url = {executor.submit(get_gravity, url): url for url in urls}
        for future in concurrent.futures.as_completed(future_to_url):
            url = future_to_url[future]
            try:
                result = future.result()
                results.append(result)
                print(len(results), result)
            except Exception as exc:
                # print(f'{url} generated an exception: {exc}')
                results.append('none')
    return results
# Main execution

if __name__ == "__main__":
    mask = df['gravity'] == 'none'
    urls = df.loc[mask, 'url'].tolist()  # Convert the URL series to a list
    gravity_results = fetch_gravity_concurrently(urls)
    df.loc[mask, 'gravity'] = gravity_results
# Out:
# 1 978885.87
# 2 979167.895
# 3 979168.79
# 4 978188.324
# 5 978873.604
# 6 979288.456
# 7 979173.866
# 8 978757.857
# 9 980304.139
# 10 978012.076
# 11 980180.818
# 12 979567.493
# 13 978513.536
# 14 980505.199
# 15 978693.089
# 16 978078.555
# 17 977983.422
# 18 978486.967

# %%
df
# Out:
#        Unnamed: 0.1  Unnamed: 0                 time  latitude  longitude  \
# 1624           1624       18146  2011-09-20 02:40:22   -4.5320  -105.2070
# 15488         15488      310423  2022-07-12 21:47:56  -22.4641  -114.0216
# 14312         14312      286551  2021-08-25 00:28:32  -27.4895   -69.2363
# 11385         11385      219295  2019-06-21 08:40:38  -30.8528  -177.5218
# 17133         17133      345840  2023-06-02 04:31:31  -23.7819   171.8772
# 10533         10533      202012  2018-10-16 02:10:13   44.2022    82.5805
# 13984         13984      281131  2021-06-30 15:07:54  -28.3361  -113.1267
# 4159           4159       57811  2013-09-24 14:08:32   27.4939    65.6874
# 15092         15092      302410  2022-03-22 18:10:50   23.4597   121.5099
# 7998           7998      139297  2016-10-17 06:14:58   -6.0033   148.8871
# 9206           9206      162342  2017-09-29 13:49:57   39.8279    68.0037
# 16897         16897      341423  2023-05-04 00:49:04   17.4696   122.3465
# 2428           2428       29133  2012-04-17 03:50:15  -32.6250   -71.3650
# 12468         12468      249697  2020-05-30 18:13:48   42.4803   143.8087
# 15180         15180      303835  2022-04-10 01:32:23    7.3666    94.4408
# 3288           3288       43822  2013-01-09 21:05:03    0.6970    92.7250
# 11346         11346      218895  2019-06-15 21:56:10  -21.1807  -174.1690
# 1735           1735       19899  2011-10-25 00:44:22  -17.8210    66.2490
#
#        depth  mag magType    nst    gap  ...  depthError  magError magNst  \
# 1624   10.00  5.7     mwc  154.0  109.7  ...         NaN       NaN    NaN
# 15488  10.00  5.6     mww  120.0   42.0  ...       1.487     0.048   41.0
# 14312  96.77  5.1     mww    NaN   34.0  ...       3.500     0.061   26.0
# 11385  10.00  5.1      mb    NaN   81.0  ...       1.900     0.106   29.0
# 17133  10.00  5.1     mww   50.0  103.0  ...       1.512     0.080   15.0
# 10533  25.12  5.2     mww    NaN   18.0  ...       3.800     0.127    6.0
# 13984  10.00  5.3     mww    NaN   46.0  ...       1.800     0.098   10.0
# 4159   20.97  5.2      mb    NaN   23.0  ...       2.700     0.050    NaN
# 15092  11.79  5.1      mb    NaN   96.0  ...       4.200     0.074   66.0
# 7998   42.00  6.8     mww    NaN   11.0  ...       1.800       NaN    NaN
# 9206   14.13  5.1     mww    NaN   47.0  ...       3.200     0.075   17.0
# 16897  19.00  5.4     mww  235.0   51.0  ...       1.707     0.056   31.0
# 2428   29.00  6.7     mww  518.0   26.9  ...         NaN       NaN    NaN
# 12468  89.00  5.6     mww    NaN   35.0  ...       1.900     0.060   27.0
# 15180   6.21  5.4     mww    NaN   21.0  ...       3.200     0.054   33.0
# 3288   29.20  5.2     mwb   95.0   50.2  ...      12.500       NaN    NaN
# 11346  13.00  6.1     mww    NaN   21.0  ...       1.700     0.052   36.0
# 1735   10.00  5.1     mwc   18.0   68.1  ...         NaN       NaN    NaN
#
#          status locationSource magSource distance  \
# 1624   reviewed             us      gcmt   394480
# 15488  reviewed             us        us   357478
# 14312  reviewed             us        us   390232
# 11385  reviewed             us        us   402399
# 17133  reviewed             us        us   378613
# 10533  reviewed             us        us   402338
# 13984  reviewed             us        us   391437
# 4159   reviewed             us        us   398027
# 15092  reviewed             us        us   370203
# 7998   reviewed             us        us   357934
# 9206   reviewed             us        us   400979
# 16897  reviewed             us        us   387476
# 2428   reviewed             us        us   396983
# 12468  reviewed             us        us   370301
# 15180  reviewed             us        us   401168
# 3288   reviewed             us        us   360313
# 11346  reviewed             us        us   384372
# 1735   reviewed             us      gcmt   359195
#
#                                                      url         force  \
# 1624   https://geodesy.noaa.gov/api/gravd/gp?lat=-4.5...  1.881471e+20
# 15488  https://geodesy.noaa.gov/api/gravd/gp?lat=-22....  2.291125e+20
# 14312  https://geodesy.noaa.gov/api/gravd/gp?lat=-27....  1.922657e+20
# 11385  https://geodesy.noaa.gov/api/gravd/gp?lat=-30....  1.808147e+20
# 17133  https://geodesy.noaa.gov/api/gravd/gp?lat=-23....  2.042474e+20
# 10533  https://geodesy.noaa.gov/api/gravd/gp?lat=44.2...  1.808695e+20
# 13984  https://geodesy.noaa.gov/api/gravd/gp?lat=-28....  1.910838e+20
# 4159   https://geodesy.noaa.gov/api/gravd/gp?lat=27.4...  1.848087e+20
# 15092  https://geodesy.noaa.gov/api/gravd/gp?lat=23.4...  2.136327e+20
# 7998   https://geodesy.noaa.gov/api/gravd/gp?lat=-6.0...  2.285292e+20
# 9206   https://geodesy.noaa.gov/api/gravd/gp?lat=39.8...  1.820976e+20
# 16897  https://geodesy.noaa.gov/api/gravd/gp?lat=17.4...  1.950105e+20
# 2428   https://geodesy.noaa.gov/api/gravd/gp?lat=-32....  1.857820e+20
# 12468  https://geodesy.noaa.gov/api/gravd/gp?lat=42.4...  2.135196e+20
# 15180  https://geodesy.noaa.gov/api/gravd/gp?lat=7.36...  1.819261e+20
# 3288   https://geodesy.noaa.gov/api/gravd/gp?lat=0.69...  2.255213e+20
# 11346  https://geodesy.noaa.gov/api/gravd/gp?lat=-21....  1.981728e+20
# 1735   https://geodesy.noaa.gov/api/gravd/gp?lat=-17....  2.269274e+20
#
#           gravity
# 1624    978885.87
# 15488  979167.895
# 14312   979168.79
# 11385  978188.324
# 17133  978873.604
# 10533  979288.456
# 13984  979173.866
# 4159   978757.857
# 15092  980304.139
# 7998   978012.076
# 9206   980180.818
# 16897  979567.493
# 2428   978513.536
# 12468  980505.199
# 15180  978693.089
# 3288   978078.555
# 11346  977983.422
# 1735   978486.967
#
# [18 rows x 28 columns]
