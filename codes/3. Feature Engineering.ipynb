# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

## Display all the columns of the dataframe
pd.pandas.set_option('display.max_columns',None)

# %%
earthquake_df = pd.read_csv('../dataset/final_dataset/raw_dataset_eda.csv')
earthquake_df.head()
# Out:
#              date_time  latitude  longitude  depth  magnitude magnitude_type  \
# 0  2011-01-01 09:56:58   -26.803    -63.136  576.8       7.00            mww
# 1  2011-01-01 09:59:36   -26.851    -63.217  592.9       5.78             mw
# 2  2011-01-02 09:23:13   -59.414    -24.469   35.0       5.10             mb
# 3  2011-01-02 15:19:31    -4.458    101.428   21.6       5.70            mwb
# 4  2011-01-02 20:20:17   -38.355    -73.326   24.0       7.20            mww
#
#      nst   gap  depth_min   rms     net              id  \
# 0  607.0  18.4        NaN  0.85      us      usp000hsdc
# 1    NaN   NaN        NaN   NaN  iscgem  iscgem16394566
# 2   52.0  95.5        NaN  1.20      us      usp000hsez
# 3  271.0  28.9        NaN  1.08      us      usp000hsfe
# 4  397.0  30.1        NaN  1.10      us      usp000hsfq
#
#                updated_date                             place        type  \
# 0  2022-10-24T02:25:20.934Z   26 km NNE of El Hoyo, Argentina  earthquake
# 1  2022-04-08T21:40:35.688Z     19 km N of El Hoyo, Argentina  earthquake
# 2  2014-11-07T01:43:20.059Z     South Sandwich Islands region  earthquake
# 3  2022-04-08T21:28:10.812Z  118 km SW of Bengkulu, Indonesia  earthquake
# 4  2022-08-09T03:48:09.579Z       42 km NNW of Carahue, Chile  earthquake
#
#    horizontal_error  depth_error  magnitude_error  magnitude_nst    status  \
# 0               NaN          NaN              NaN            NaN  reviewed
# 1               NaN         25.0              0.4            NaN  reviewed
# 2               NaN          NaN              NaN           13.0  reviewed
# 3               NaN          3.2              NaN            NaN  reviewed
# 4               NaN          NaN              NaN            NaN  reviewed
#
#   location_source magnitude_source  distance  \
# 0              us               us    380543
# 1          iscgem           iscgem    380548
# 2              us               us    383580
# 3              us               us    384394
# 4              us               us    385093
#
#                                                  url   gravity         force  \
# 0  https://geodesy.noaa.gov/api/gravd/gp?lat=-26....  9.818623  2.020842e+20
# 1  https://geodesy.noaa.gov/api/gravd/gp?lat=-26....  9.794050  2.020789e+20
# 2  https://geodesy.noaa.gov/api/gravd/gp?lat=-59....  9.793398  1.988969e+20
# 3  https://geodesy.noaa.gov/api/gravd/gp?lat=-4.4...  9.802458  1.980554e+20
# 4  https://geodesy.noaa.gov/api/gravd/gp?lat=-38....  9.790649  1.973371e+20
#
#    year  month  day  hour  minutes  day_name
# 0  2011      1    1     9       56  Saturday
# 1  2011      1    1     9       59  Saturday
# 2  2011      1    2     9       23    Sunday
# 3  2011      1    2    15       19    Sunday
# 4  2011      1    2    20       20    Sunday

# %% [markdown]
# ### Remove column which are not important for observation and research

# %%
column_to_drop = [
    'nst', 
    'gap', 
    'rms', 
    'net', 
    'id', 
    'updated_date', 
    'place', 
    'type', 
    'horizontal_error', 
    'depth_error',
    'magnitude_error',
    'magnitude_nst',
    'status',
    'location_source',
    'magnitude_source',
    'url', 
    'depth_min',
    'day_name', 
    'date_time'
]
earthquake_df = earthquake_df.drop(columns=column_to_drop, axis=1 )

# %%
earthquake_df.head(2)
# Out:
#    latitude  longitude  depth  magnitude magnitude_type  distance   gravity  \
# 0   -26.803    -63.136  576.8       7.00            mww    380543  9.818623
# 1   -26.851    -63.217  592.9       5.78             mw    380548  9.794050
#
#           force  year  month  day  hour  minutes
# 0  2.020842e+20  2011      1    1     9       56
# 1  2.020789e+20  2011      1    1     9       59

# %% [markdown]
# ### Bringing reatures onto same scale

# %% [markdown]
# ## Feature Engineering for Training Dataset

# %% [markdown]
# ### Handel Missing Value

# %% [markdown]
# #### Missing value for Categorical Feature

# %%
# there is no any missing values in the categorical columns
earthquake_df.isnull().sum()
# Out:
# latitude          0
# longitude         0
# depth             0
# magnitude         0
# magnitude_type    0
# distance          0
# gravity           0
# force             0
# year              0
# month             0
# day               0
# hour              0
# minutes           0
# dtype: int64

# %% [markdown]
# ##### There is not any missing value in Categorical Feature

# %% [markdown]
# #### Missing value for Numerical Feature

# %%
# also there is no any missing value in the numerical columns
earthquake_df.select_dtypes(exclude=object).isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# magnitude    0
# distance     0
# gravity      0
# force        0
# year         0
# month        0
# day          0
# hour         0
# minutes      0
# dtype: int64

# %% [markdown]
# ### Perform log transformation to make skewed data to form Gaussian distribution

# %%
numerical_feature = ['depth', 'distance', 'gravity', 'force']
for feature in numerical_feature:
    earthquake_df[feature]=np.log(earthquake_df[feature])
# Out:
# /Users/ghanshyamsingh/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
earthquake_df.head()
# Out:
#    latitude  longitude     depth  magnitude magnitude_type   distance  \
# 0   -26.803    -63.136  6.357496       7.00            mww  12.849354
# 1   -26.851    -63.217  6.385026       5.78             mw  12.849368
# 2   -59.414    -24.469  3.555348       5.10             mb  12.857303
# 3    -4.458    101.428  3.072693       5.70            mwb  12.859423
# 4   -38.355    -73.326  3.178054       7.20            mww  12.861240
#
#     gravity      force  year  month  day  hour  minutes
# 0  2.284281  46.755216  2011      1    1     9       56
# 1  2.281775  46.755190  2011      1    1     9       59
# 2  2.281708  46.739318  2011      1    2     9       23
# 3  2.282633  46.735078  2011      1    2    15       19
# 4  2.281428  46.731445  2011      1    2    20       20

# %% [markdown]
# #### Handling Rare Categorical Feature
#
# Remove categorical variables that are present less than 1% of the observation

# %%
# getting the magnitude type which occoured more than 1% in the data set and replacing with 'rare_mt'
magnitude_type = (earthquake_df['magnitude_type'].value_counts() / len(earthquake_df) * 100 > 1)

false_types = magnitude_type[magnitude_type == False].index.tolist()
earthquake_df['magnitude_type'] = earthquake_df['magnitude_type'].apply(lambda x: 'rare_mt' if x in false_types else x)
earthquake_df['magnitude_type'].value_counts()
# Out:
# magnitude_type
# mww        9239
# mb         6237
# mwc        1345
# mwb         857
# mwr         200
# rare_mt     181
# Name: count, dtype: int64

# %% [markdown]
# ### Handling Categorical Feature into numerical Variable

# %%
earthquake_df = pd.concat([earthquake_df.drop(columns=['magnitude_type'], axis=1),pd.get_dummies(earthquake_df['magnitude_type'])], axis=1)


boolean_columns = earthquake_df.select_dtypes(include=['bool']).columns

# Convert boolean columns to integers
earthquake_df[boolean_columns] = earthquake_df[boolean_columns].astype(int)
earthquake_df = earthquake_df[np.isfinite(earthquake_df).all(1)]

# %%
train_df_scaled, test_df_scaled= train_test_split(earthquake_df, test_size=0.2, random_state=101)

# %%
# Out:
#        latitude  longitude     depth  magnitude   distance   gravity  \
# 5797    -6.7306   155.0899  3.555348        5.1  12.808255  2.280247
# 3186     2.4210    90.4340  3.430756        5.1  12.866583  2.282207
# 13233  -20.3307  -173.8138  2.302585        5.1  12.821645  2.281148
# 16503  -59.4030   -17.9994  2.302585        5.9  12.913470  2.280851
# 8853   -54.3240   159.1913  2.302585        5.1  12.865658  2.280331
# ...         ...        ...       ...        ...        ...       ...
# 5698     5.7531    61.3264  2.302585        5.4  12.821045  2.280327
# 8012    44.0505   148.1035  3.367296        5.9  12.863841  2.282966
# 17751    8.5266   126.4161  3.688879        7.6  12.902644  2.283954
# 17937  -53.1275  -117.7908  2.302585        5.4  12.883997  2.283723
# 13157   -2.9809   118.8940  2.890372        5.7  12.844238  2.280542
#
#            force  year  month  day  hour  minutes  mb  mwb  mwc  mwr  mww  \
# 5797   46.837415  2014     12   23    21       19   1    0    0    0    0
# 3186   46.720759  2012     12    6     2       24   1    0    0    0    0
# 13233  46.810636  2021      2    3    11       11   1    0    0    0    0
# 16503  46.626985  2023      3    3     4       53   0    0    0    0    1
# 8853   46.722609  2017      6    1    20        4   1    0    0    0    0
# ...          ...   ...    ...  ...   ...      ...  ..  ...  ...  ...  ...
# 5698   46.811836  2014     11   28    13       23   0    0    1    0    0
# 8012   46.726243  2016     10   23    20       25   0    0    0    0    1
# 17751  46.648637  2023     12    2    14       37   0    0    0    0    1
# 17937  46.685931  2023     12   27    15       36   0    0    0    0    1
# 13157  46.765449  2021      1   14     6       35   0    0    0    0    1
#
#        rare_mt
# 5797         0
# 3186         0
# 13233        0
# 16503        0
# 8853         0
# ...        ...
# 5698         0
# 8012         0
# 17751        0
# 17937        0
# 13157        0
#
# [14442 rows x 18 columns]

# %%
train_df_scaled, test_df_scaled= train_test_split(earthquake_df, test_size=0.2, random_state=101)
train_df_scaled.to_csv('../dataset/final_dataset/gkm/train.csv', index=False)
test_df_scaled.to_csv('../dataset/final_dataset/gkm/test.csv', index=False)
